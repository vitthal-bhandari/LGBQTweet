# %%
import os
import pandas as pd
import simpledorff
from sklearn.metrics import cohen_kappa_score
import warnings
warnings.filterwarnings("ignore")

# %%
# Set the folder path where the CSV files are located
folder_path = r'C:\Users\nithi\Downloads\LGBQTweet-master\LGBQTweet-master\dataset\labeled'

# Create an empty list to store the dataframes
dataframes = []

# Loop through all the CSV files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        
        # Read the CSV file into a dataframe
        filepath = os.path.join(folder_path, filename)
        df = pd.read_csv(filepath)
        
        # Select the desired columns
        df = df[['Unnamed: 0', 'text', 'annotation', 'annotation_agent', 'id']]
        
        # Rename the 'Unnamed: 0' column to 'ID'
        df = df.rename(columns={'Unnamed: 0': 'ID'})
        
        # Replace values in the 'annotation' column
        df['annotation'] = df['annotation'].replace({
            '1 (extremely positive)': 'non-hateful',
            '2 (positive)': 'non-hateful',
            '3 (neutral)': 'non-hateful',
            '4 (hateful)': 'hateful',
            '5 (extremely hateful)': 'hateful'
        })
        
        # Filter the dataframe to include only 'hateful' or 'non-hateful' rows
        df = df[df['annotation'].isin(['hateful', 'non-hateful'])]
        
        # Considering only some columns
        df = df[['id', 'text', 'annotation', 'annotation_agent']]
        
        # Append the dataframe to the list
        dataframes.append(df)

# Concatenate all the dataframes in the list into a single dataframe
combined_df = pd.concat(dataframes, ignore_index=True)

# Print the combined dataframe
combined_df
# Out:
#         id                                               text   annotation  \
# 0     2501            i am so excited to gay it up today damN  non-hateful
# 1     2502  Had the pleasure of Speaking at my colleges 9t...  non-hateful
# 2     2503  "If you're black, if you're white, if you're g...  non-hateful
# 3     2504  Thinking &amp; speaking mindfully &amp; authen...  non-hateful
# 4     2505  The MTF transsexual on Springer had no idea sh...      hateful
# ...    ...                                                ...          ...
# 1824  2244  Born intersex, I am so glad I got a generous s...  non-hateful
# 1825  2245  Tell me: yay or nay to this title for a grant ...      hateful
# 1826  2246            Georgina Sparks should’ve been bisexual      hateful
# 1827  2247  I understand being mad that Darren is performi...  non-hateful
# 1828  2248  ⚠️I need everyone who has ever felt they were ...  non-hateful
#
#      annotation_agent
# 0             argilla
# 1             argilla
# 2             argilla
# 3             argilla
# 4             argilla
# ...               ...
# 1824          argilla
# 1825          argilla
# 1826          argilla
# 1827          argilla
# 1828          argilla
#
# [1829 rows x 4 columns]

# %%
# Read the labeled_sentences dataframe from file
labeled_sentences = pd.read_json(r'updated_10k.json')

# Convert the values in the 'label' column to lowercase
labeled_sentences['label'] = labeled_sentences['label'].str.lower()

# Replace any characters that are not 'hateful' or 'non-hateful' with an empty string
labeled_sentences['label'] = labeled_sentences['label'].str.replace('[^a-zA-Z ]', '')

# Map the values to 'hateful' or 'non-hateful'
labeled_sentences['label'] = labeled_sentences['label'].map({'hateful': 'hateful', 'nonhateful': 'non-hateful'})

# Considering only some columns
labeled_sentences =labeled_sentences[['id', 'text', 'label', 'reason']]

# Print the resulting dataframe
labeled_sentences
# Out:
#           id                                               text        label  \
# 0          1  if you need to soothe a flustered Caucasian th...      hateful
# 1          2  Afaik I’m not intersex and I don’t know enough...      hateful
# 2          3  Queer &amp; trans kids, I know it's not this e...      hateful
# 3          4  I got called 'gay' (as if it's an insult to be...      hateful
# 4          5  Valid to unfollow me at any time but if you do...      hateful
# ...      ...                                                ...          ...
# 11713  11714  'Dillon Callum Jackson' is bisexual ahahahah I...      hateful
# 11714  11715  Every STRAIGHT girl has a ATLEAST one GAY frie...  non-hateful
# 11715  11716  who’s the pos in a thousand oaks with a shitty...      hateful
# 11716  11717  lesbian character : gets screen time\nme : !!\...      hateful
# 11717  11718  every time someone mentions they are Asexual, ...      hateful
#
#                                                   reason
# 0      The sentence is classified as Hateful because ...
# 1      hateful - The sentence contains a slur ("c*ntb...
# 2      Hateful. The sentence incites fear and discrim...
# 3                                                hateful
# 4      Hateful. The sentence contains a threat and an...
# ...                                                  ...
# 11713  hateful - The sentence contains a derogatory t...
# 11714  The sentence is non-hateful because it does no...
# 11715  The sentence contains explicit references to t...
# 11716  The sentence contains offensive language and e...
# 11717  Hateful - The sentence contains offensive lang...
#
# [11718 rows x 4 columns]

# %%
# Merge the dataframes based on the 'text' column
merged_df = pd.merge(combined_df, labeled_sentences, on='id', suffixes=('_combined', '_labeled'))
merged_df = merged_df.rename(columns={'annotation': 'human_annotation', 'label': 'gpt_annotation'})
merged_df.head(3)
# Out:
#      id                                      text_combined human_annotation  \
# 0  2501            i am so excited to gay it up today damN      non-hateful
# 1  2502  Had the pleasure of Speaking at my colleges 9t...      non-hateful
# 2  2503  "If you're black, if you're white, if you're g...      non-hateful
#
#   annotation_agent                                       text_labeled  \
# 0          argilla            i am so excited to gay it up today damN
# 1          argilla  Had the pleasure of Speaking at my colleges 9t...
# 2          argilla  "If you're black, if you're white, if you're g...
#
#   gpt_annotation                                             reason
# 0        hateful  The sentence should be classified as hateful b...
# 1    non-hateful  The sentence is non-hateful because it refers ...
# 2    non-hateful  The sentence promotes inclusivity and love tow...

# %%
# Considering only some columns
merged_df = merged_df[['id', 'text_combined', 'human_annotation', 'gpt_annotation', 'reason']]

# Renaming column name from text_combined to text
merged_df = merged_df.rename(columns={'text_combined': 'text'})

# Printing merged dataframe
merged_df
# Out:
#         id                                               text  \
# 0     2501            i am so excited to gay it up today damN
# 1     2502  Had the pleasure of Speaking at my colleges 9t...
# 2     2503  "If you're black, if you're white, if you're g...
# 3     2504  Thinking &amp; speaking mindfully &amp; authen...
# 4     2505  The MTF transsexual on Springer had no idea sh...
# ...    ...                                                ...
# 1824  2244  Born intersex, I am so glad I got a generous s...
# 1825  2245  Tell me: yay or nay to this title for a grant ...
# 1826  2246            Georgina Sparks should’ve been bisexual
# 1827  2247  I understand being mad that Darren is performi...
# 1828  2248  ⚠️I need everyone who has ever felt they were ...
#
#      human_annotation gpt_annotation  \
# 0         non-hateful        hateful
# 1         non-hateful    non-hateful
# 2         non-hateful    non-hateful
# 3         non-hateful    non-hateful
# 4             hateful        hateful
# ...               ...            ...
# 1824      non-hateful    non-hateful
# 1825          hateful    non-hateful
# 1826          hateful    non-hateful
# 1827      non-hateful    non-hateful
# 1828      non-hateful    non-hateful
#
#                                                  reason
# 0     The sentence should be classified as hateful b...
# 1     The sentence is non-hateful because it refers ...
# 2     The sentence promotes inclusivity and love tow...
# 3     The sentence is non-hateful because it promote...
# 4     The sentence contains a direct reference to a ...
# ...                                                 ...
# 1824  The reason for the non-hateful classification ...
# 1825  The sentence is non-hateful because it is a re...
# 1826  The sentence does not contain any explicit ref...
# 1827  The sentence does not contain any explicit ref...
# 1828  The reason for the non-hateful classification ...
#
# [1829 rows x 5 columns]

# %%
# Dropping null values from the merged dataframe
merged_df.dropna(inplace=True)

# %%
# Checking the shape of the data after dropping null values
merged_df
# Out:
#         id                                               text  \
# 0     2501            i am so excited to gay it up today damN
# 1     2502  Had the pleasure of Speaking at my colleges 9t...
# 2     2503  "If you're black, if you're white, if you're g...
# 3     2504  Thinking &amp; speaking mindfully &amp; authen...
# 4     2505  The MTF transsexual on Springer had no idea sh...
# ...    ...                                                ...
# 1824  2244  Born intersex, I am so glad I got a generous s...
# 1825  2245  Tell me: yay or nay to this title for a grant ...
# 1826  2246            Georgina Sparks should’ve been bisexual
# 1827  2247  I understand being mad that Darren is performi...
# 1828  2248  ⚠️I need everyone who has ever felt they were ...
#
#      human_annotation gpt_annotation  \
# 0         non-hateful        hateful
# 1         non-hateful    non-hateful
# 2         non-hateful    non-hateful
# 3         non-hateful    non-hateful
# 4             hateful        hateful
# ...               ...            ...
# 1824      non-hateful    non-hateful
# 1825          hateful    non-hateful
# 1826          hateful    non-hateful
# 1827      non-hateful    non-hateful
# 1828      non-hateful    non-hateful
#
#                                                  reason
# 0     The sentence should be classified as hateful b...
# 1     The sentence is non-hateful because it refers ...
# 2     The sentence promotes inclusivity and love tow...
# 3     The sentence is non-hateful because it promote...
# 4     The sentence contains a direct reference to a ...
# ...                                                 ...
# 1824  The reason for the non-hateful classification ...
# 1825  The sentence is non-hateful because it is a re...
# 1826  The sentence does not contain any explicit ref...
# 1827  The sentence does not contain any explicit ref...
# 1828  The reason for the non-hateful classification ...
#
# [1828 rows x 5 columns]

# %%
matched_rows = merged_df[merged_df['human_annotation'] == merged_df['gpt_annotation']]
matched_rows
# Out:
#         id                                               text  \
# 1     2502  Had the pleasure of Speaking at my colleges 9t...
# 2     2503  "If you're black, if you're white, if you're g...
# 3     2504  Thinking &amp; speaking mindfully &amp; authen...
# 4     2505  The MTF transsexual on Springer had no idea sh...
# 5     2506   i cant believe my BOYFRIEND ASHER is FUCKING GAY
# ...    ...                                                ...
# 1821  2241  Y'know Pitch Perfect was amazing but there was...
# 1823  2243         DON'T YOU MARRY THE FOREIGN QUEER JENNIFER
# 1824  2244  Born intersex, I am so glad I got a generous s...
# 1827  2247  I understand being mad that Darren is performi...
# 1828  2248  ⚠️I need everyone who has ever felt they were ...
#
#      human_annotation gpt_annotation  \
# 1         non-hateful    non-hateful
# 2         non-hateful    non-hateful
# 3         non-hateful    non-hateful
# 4             hateful        hateful
# 5             hateful        hateful
# ...               ...            ...
# 1821      non-hateful    non-hateful
# 1823          hateful        hateful
# 1824      non-hateful    non-hateful
# 1827      non-hateful    non-hateful
# 1828      non-hateful    non-hateful
#
#                                                  reason
# 1     The sentence is non-hateful because it refers ...
# 2     The sentence promotes inclusivity and love tow...
# 3     The sentence is non-hateful because it promote...
# 4     The sentence contains a direct reference to a ...
# 5                                               hateful
# ...                                                 ...
# 1821  The sentence is non-hateful because it is expr...
# 1823  The sentence contains a direct reference to th...
# 1824  The reason for the non-hateful classification ...
# 1827  The sentence does not contain any explicit ref...
# 1828  The reason for the non-hateful classification ...
#
# [1157 rows x 5 columns]

# %%
unmatched_rows = merged_df[merged_df['human_annotation'] != merged_df['gpt_annotation']]
unmatched_rows
# Out:
#         id                                               text  \
# 0     2501            i am so excited to gay it up today damN
# 8     2512  tbh im so...SO so done over people being judge...
# 12    2519  straight people Love to make life hell for LGB...
# 13    2520  It's fucking 2017 and folk still think mocking...
# 16    2524  Doesn't matter if someone gay, bisexual, or le...
# ...    ...                                                ...
# 1817  2235  Fucking Jared leto ruined my lesbian fantasy a...
# 1819  2237    Crap I think my header represents lesbians....?
# 1822  2242  great trope: people asking juzo if he's some s...
# 1825  2245  Tell me: yay or nay to this title for a grant ...
# 1826  2246            Georgina Sparks should’ve been bisexual
#
#      human_annotation gpt_annotation  \
# 0         non-hateful        hateful
# 8         non-hateful        hateful
# 12        non-hateful        hateful
# 13        non-hateful        hateful
# 16        non-hateful        hateful
# ...               ...            ...
# 1817      non-hateful        hateful
# 1819          hateful    non-hateful
# 1822          hateful    non-hateful
# 1825          hateful    non-hateful
# 1826          hateful    non-hateful
#
#                                                  reason
# 0     The sentence should be classified as hateful b...
# 8     The sentence should be classified as hateful b...
# 12    hateful - The sentence contains an explicit re...
# 13                                              hateful
# 16    hateful. The sentence contains an explicit ref...
# ...                                                 ...
# 1817  The sentence is classified as hateful because ...
# 1819  The sentence does not contain any explicit ref...
# 1822  The sentence does not contain any explicit ref...
# 1825  The sentence is non-hateful because it is a re...
# 1826  The sentence does not contain any explicit ref...
#
# [671 rows x 5 columns]

# %%
# Convert the 'human_annotation' and 'gpt_annotation' columns to categorical variables
categories = ['non-hateful', 'hateful']
merged_df['human_annotation'] = pd.Categorical(merged_df['human_annotation'], categories=categories)
merged_df['gpt_annotation'] = pd.Categorical(merged_df['gpt_annotation'], categories=categories)

# Compute the Cohen's kappa score between the 'human_annotation' and 'gpt_annotation' columns
kappa = cohen_kappa_score(merged_df['human_annotation'], merged_df['gpt_annotation'], labels=['non-hateful', 'hateful'])

print(f"Cohen's kappa score: {kappa}")
# Out:
# Cohen's kappa score: 0.2828614726916402

# %%
# Create a new DataFrame with the required columns
data = pd.DataFrame(columns=["document_id", "annotator_id", "annotation"])

# Loop through the rows of the merged_df DataFrame
for i, row in merged_df.iterrows():
    # Add a row for the human annotation
    data = data.append({"document_id": i, "annotator_id": "human", "annotation": row["human_annotation"]}, ignore_index=True)
    # Add a row for the GPT annotation
    data = data.append({"document_id": i, "annotator_id": "gpt", "annotation": row["gpt_annotation"]}, ignore_index=True)

# Print the resulting DataFrame
data
# Out:
#      document_id annotator_id   annotation
# 0              0        human  non-hateful
# 1              0          gpt      hateful
# 2              1        human  non-hateful
# 3              1          gpt  non-hateful
# 4              2        human  non-hateful
# ...          ...          ...          ...
# 3651        1826          gpt  non-hateful
# 3652        1827        human  non-hateful
# 3653        1827          gpt  non-hateful
# 3654        1828        human  non-hateful
# 3655        1828          gpt  non-hateful
#
# [3656 rows x 3 columns]

# %%
# Calculate the Krippendorff's alpha score
alpha_score = simpledorff.calculate_krippendorffs_alpha_for_df(data, experiment_col="document_id", annotator_col="annotator_id", class_col="annotation")

# Print the alpha score
print(f"Krippendorff's alpha: {alpha_score}")
# Out:
# Krippendorff's alpha: 0.2301178537267713
